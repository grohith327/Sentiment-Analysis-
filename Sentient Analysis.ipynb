# %%
with open("/Users/rohith/Documents/Datasets/sentiment_labelled_sentences/amazon_cells_labelled.txt") as f1:
    lines = f1.readlines()


with open("/Users/rohith/Documents/Datasets/sentiment_labelled_sentences/imdb_labelled.txt") as f1:
    temp = f1.readlines()
    lines=lines+temp

with open("/Users/rohith/Documents/Datasets/sentiment_labelled_sentences/yelp_labelled.txt") as f1:
    temp = f1.readlines()
    lines=lines+temp

# %%
x = []
y = []
for value in lines:
    #print(value)
    temp = value.split('\t')
    x.append(temp[0])
    temp[1].replace('\n','')
    y.append(int(temp[1]))

# %%
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=2500,split=' ')
tokenizer.fit_on_texts(x)
print(tokenizer.word_index)
# Out:
# Using TensorFlow backend.
# {'limited': 1994, 'uhura': 4166, 'ngage': 2461, 'secondly': 3202, 'magnetic': 2515, 'personally': 2062, 'yellow': 4961, 'sleek': 1521, 'four': 1222, 'sleep': 2049, "friend's": 1469, 'mirage': 5261, 'unwelcome': 5109, 'succulent': 4759, 'captain': 4296, 'hate': 528, 'unexperienced': 5192, 'poorly': 683, 'stinks': 1418, 'whose': 2290, 'replacementr': 2682, 'ceases': 1847, 'spew': 3188, 'sweetest': 2946, 'contained': 1330, 'dialing': 1584, 'presents': 1317, 'fingernails': 3028, 'insipid': 3016, 'slipping': 2780, 'whatsoever': 680, 'under': 501, 'rickman': 4391, 'lord': 2093, 'sorry': 1247, 'welcome': 4678, 'worth': 180, 'sinking': 4255, 'swivel': 2879, 'allergy': 5171, 'louder': 2648, 'risk': 2531, 'bruschetta': 5103, 'yelps': 3491, 'blanket': 4601, 'rise': 3296, 'relatively': 1517, 'smack': 3370, 'v265': 2858, 'every': 141, 'jack': 1680, 'bertolucci': 3862, 'hs850': 2375, 'monkeys': 2367, 'tickets': 3134, "we'll": 1075, 'wooden': 1245, 'loneliness': 2103, 'venue': 4843, 'upload': 2730, 'bamboo': 4599, 'frozen': 1435, 'honor': 4748, 'shouting': 2848, 'employees': 5193, 'falwell': 3617, 'settings': 3344, 'glued': 2630, 'ups': 1017, 'confidence': 4467, 'enjoy': 398, 'forget': 893, 'entertained': 4213, 'bill': 1479, 'force': 4242, 'specially': 2485, 'buildings': 3488, 'phones': 443, 'consistent': 2099, 'bubbling': 2611, 'bacon': 873, 'japanese': 1888, 'portrayed': 3444, 'batch': 5201, 'chef': 1087, 'elegant': 1502, 'second': 516, 'fabulous': 1215, 'flakes': 3515, 'gorman': 4415, 'air': 1945, 'specs': 2928, 'sincere': 4413, 'theory': 2749, 'even': 63, 'established': 3745, "black's": 3779, 'dialogs': 3078, 'eccleston': 3288, 'celebrity': 4276, 'forgetting': 1881, 'ruthless': 1370, 'saved': 2899, 'cooking': 5152, 'fingers': 2686, 'asia': 2661, 'lights': 2480, 'bonuses': 4458, 'absolute': 4957, 'above': 609, 'cars': 3996, 'new': 161, 'tips': 1546, 'ever': 65, 'croutons': 4943, 'disney': 4433, 'told': 560, 'relationships': 2011, 'pats': 5187, 'plater': 4977, 'hero': 3888, 'philippa': 4180, 'reporter': 4262, 'pancakes': 2216, 'join': 5080, "stanwyck's": 3577, 'never': 98, 'disposable': 2816, 'meh': 2143, 'here': 64, 'screamy': 3476, 'protection': 1110, 'studio': 1963, 'greedy': 4729, 'cult': 834, '100': 1240, "aren't": 828, 'mozzarella': 5107, 'dee': 4304, 'celebration': 3252, 'dry': 850, 'remotely': 1934, 'kids': 461, 'daughter': 1324, 'uplifting': 1777, 'rests': 2919, 'items': 2354, 'leaves': 1354, 'article': 5124, 'controversy': 3379, 'babysitting': 4462, 'taped': 1877, "i'd": 295, 'bennett': 4014, 'smoke': 1698, 'browsing': 2361, 'military': 4538, "i'm": 100, 'spotty': 5230, 'changes': 4115, 'cancellation': 2876, 'bbq': 4739, 'golden': 5101, 'fantastic': 269, 'secure': 1567, 'owed': 3990, 'straw': 3716, 'highly': 200, 'brought': 1432, 'moral': 2029, 'guests': 2017, 'glance': 1378, 'total': 800, 'schilling': 3473, 'unit': 554, 'hunan': 5071, 'plot': 172, 'dna': 2368, 'rapidly': 5056, 'would': 54, 'catchy': 3826, 'keith': 3422, '42': 2743, 'negative': 1283, 'tenders': 4558, 'insult': 1044, 'chargers': 1147, 'edward': 3679, 'music': 248, 'giallo': 1413, 'recommend': 103, 'strike': 4823, 'sexy': 4561, 'e2': 2723, 'type': 922, 'tell': 387, 'sappiest': 3240, 'elias': 3389, 'tailored': 4555, 'ir': 2875, 'females': 3982, 'tranquillity': 3837, 'breeders': 3770, 'relax': 4978, 'oscar': 1381, 'schrader': 1827, 'phony': 3814, 'award': 3948, 'hurt': 1594, 'warn': 4345, 'phone': 28, 'warm': 645, 'pecan': 4889, 'former': 3536, 'excellent': 91, '90': 1036, 'treatments': 4081, 'hold': 655, '95': 3474, 'proven': 4972, 'must': 259, 'me': 70, 'directorial': 1919, 'word': 565, 'room': 597, 'shame': 1978, 'barcelona': 3650, 'setup': 1135, 'work': 87, 'worn': 2736, 'movies': 166, 'era': 1177, 'install': 1612, 'akin': 3167, 'elegantly': 4774, 'my': 16, 'example': 1372, 'scripting': 4286, 'grimes': 4203, 'phrase': 3989, 'salesman': 4474, 'vodka': 4592, 'insulin': 3908, 'omelets': 4560, 'estate': 4473, 'give': 204, 'indie': 3278, 'climax': 3890, 'skype': 1596, ...

# %%
from keras.preprocessing.sequence import pad_sequences

X = tokenizer.texts_to_sequences(x)
X = pad_sequences(X)

# %%
import numpy as np 

Y = []
for val in y:
    if(val == 0):
        Y.append([1,0])
    else:
        Y.append([0,1])
Y = np.array(Y)

# %%
print(X.shape)
# Out:
# (3000, 61)

# %%
import keras 
from keras.layers import Embedding, LSTM, Dense
from keras.models import Sequential

model = Sequential()
model.add(Embedding(2500,128,input_length=X.shape[1],dropout=0.2))
model.add(LSTM(300, dropout_U=0.2,dropout_W=0.2))
model.add(Dense(2,activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,optimizer='adam',metrics=['accuracy'])

print(model.summary())
# Out:
# /Users/rohith/anaconda3/envs/projects/lib/python2.7/site-packages/ipykernel_launcher.py:6: UserWarning: The `dropout` argument is no longer support in `Embedding`. You can apply a `keras.layers.SpatialDropout1D` layer right after the `Embedding` layer to get the same behavior.
#
# /Users/rohith/anaconda3/envs/projects/lib/python2.7/site-packages/ipykernel_launcher.py:7: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(300, dropout=0.2, recurrent_dropout=0.2)`
#   import sys
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 61, 128)           320000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 300)               514800
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 602
# =================================================================
# Total params: 835,402
# Trainable params: 835,402
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X,Y,train_size=0.8)
# Out:
# /Users/rohith/anaconda3/envs/projects/lib/python2.7/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
model.fit(x_train,y_train,epochs=10,verbose=2,batch_size=32)
# Out:
# Epoch 1/10
#  - 24s - loss: 0.6445 - acc: 0.6362
# Epoch 2/10
#  - 27s - loss: 0.3817 - acc: 0.8396
# Epoch 3/10
#  - 25s - loss: 0.2241 - acc: 0.9208
# Epoch 4/10
#  - 25s - loss: 0.1947 - acc: 0.9283
# Epoch 5/10
#  - 25s - loss: 0.1243 - acc: 0.9575
# Epoch 6/10
#  - 25s - loss: 0.0666 - acc: 0.9842
# Epoch 7/10
#  - 26s - loss: 0.0473 - acc: 0.9896
# Epoch 8/10
#  - 25s - loss: 0.0432 - acc: 0.9867
# Epoch 9/10
#  - 25s - loss: 0.0440 - acc: 0.9883
# Epoch 10/10
#  - 25s - loss: 0.0282 - acc: 0.9921

# %%
print(model.evaluate(x_test,y_test)[1])
# Out:
# 600/600 [==============================] - 2s 3ms/step
# 0.820000000795
